# %% [markdown]
# # List (Creation, Modification and Access):
#
# 1. List Creation:
# a. Create a list named age_list with five integer elements. For eg., [24, 25, 26, 27, 28]
# b. Create a list named name_list with five string elements.

# %%
age_list=[40,35,50,25,18]

# %%
name_list=["rashid","siniya","chelsa","indrajith","anisha"]

# %% [markdown]
# # 2.list Operations / Modifications.
#
# - Append the string "Yazhini" to name_list.
# - Insert the element 30 at index 2 in age_list.
# - Remove the string "Yazhini" from name_list.
# - Pop the last element from age_list.
# - Extend the age_list with additional ages [29, 30, 26].
# - Sort age_list in descending order.
# - Find Max age, Min age and sum of all ages from age_list.

# %%
name_list.append("Yazhini")

# %%
name_list
# Out:
# ['rashid', 'siniya', 'chelsa', 'indrajith', 'anisha', 'Yazhini']

# %%
age_list.insert(2,30)
age_list
# Out:
# [40, 35, 30, 50, 25, 18]

# %%
name_list.remove("Yazhini")
name_list
# Out:
# ['rashid', 'siniya', 'chelsa', 'indrajith', 'anisha']

# %%
age_list.pop()
age_list
# Out:
# [40, 35, 30, 50, 25]

# %%
age_list.extend([29,30,26])
age_list
# Out:
# [40, 35, 30, 50, 25, 29, 30, 26]

# %%
age_list.sort(reverse=True)
age_list
# Out:
# [50, 40, 35, 30, 30, 29, 26, 25]

# %%
max_age=max(age_list)
min_age=min(age_list)
total_age=sum(age_list)
print (f"max_age:{max_age},min_age:{min_age},total_age:{total_age}")
# Out:
# max_age:50,min_age:25,total_age:265

# %% [markdown]
# # 3. Accessing List Elements:
# - Print the first element of name_list.
# - Print the last element of name_list.
# - Print the elements from index 2 to index 4 in name_list.
# - Print the elements of name_list in reverse order.

# %%
name_list[0]
# Out:
# 'rashid'

# %%
name_list[-1]
# Out:
# 'anisha'

# %%
name_list[2:5]
# Out:
# ['chelsa', 'indrajith', 'anisha']

# %%
name_list[::-1]
# Out:
# ['anisha', 'indrajith', 'chelsa', 'siniya', 'rashid']

# %% [markdown]
# # Dictionary (Creation, Modification and Access):
# - Create a dictionary named student_marks that maps the names of five
# students to their marks (use scale of from 0 to 100).
# - Access and print the mark of a specific student, of your choice.
# - Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
# - Update the mark of any one older student to 82.
# - e. Use the keys(), values(), and items() methods to print all keys, values, and
# key-value pairs in the student_marks dictionary.

# %%
student_marks={"name":["ravi","raju","ramu","raghu","rio"],"marks":[35,76,85,97,55]}
student_marks
# Out:
# {'name': ['ravi', 'raju', 'ramu', 'raghu', 'rio'],
#  'marks': [35, 76, 85, 97, 55]}

# %%
student_marks["name"][3],student_marks["marks"][3]
# Out:
# ('raghu', 97)

# %%
student_marks["name"].append("janani"),student_marks["marks"].append(80)
student_marks
# Out:
# {'name': ['ravi', 'raju', 'ramu', 'raghu', 'rio', 'janani'],
#  'marks': [35, 76, 85, 97, 55, 80]}

# %%
student_marks["marks"][1]=82
student_marks
# Out:
# {'name': ['ravi', 'raju', 'ramu', 'raghu', 'rio', 'janani'],
#  'marks': [35, 82, 85, 97, 55, 80]}

# %%
student_marks.keys()
# Out:
# dict_keys(['name', 'marks'])

# %%
student_marks.values()
# Out:
# dict_values([['ravi', 'raju', 'ramu', 'raghu', 'rio', 'janani'], [35, 82, 85, 97, 55, 80]])

# %%
student_marks.items()
# Out:
# dict_items([('name', ['ravi', 'raju', 'ramu', 'raghu', 'rio', 'janani']), ('marks', [35, 82, 85, 97, 55, 80])])

# %% [markdown]
# # Sets (Operations):
# a. Create a set called my_set with following values:
# ['a','e','i','o','u','a','a','i']
# Analyse the output and provide explanation for the same.
# b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide
# an explanation.
# c. Create two sets:
#
# set1 with values: {1, 3, 5, 7, 9}
# set2 with values: {2, 3, 5, 8, 10}
#
# d. Compute and print the union and intersection of set1 and set2.

# %%
my_set={'a','e','i','o','u','a','a','i'}
my_set
# every elements inside a set is unique,if you try to add duplicates python automatically remove and set is unorderd.
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
my_set[4]='s'
# showing type error- set is unorderd , unindexed and set cannot store elements in fixed position.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 my_set[4]='s'
#       2 # showing type error- set is unorderd , unindexed and set cannot store elements in fixed position.
#
# TypeError: 'set' object does not support item assignment

# %%
set1={1,3,5,7,9,}
set1
# Out:
# {1, 3, 5, 7, 9}

# %%
set2={2,3,5,8,10}
set2
# Out:
# {2, 3, 5, 8, 10}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
set1.intersection(set2)
# Out:
# {3, 5}

# %% [markdown]
# # Operators & Conditional Statements :
# (IF, ELIF, ELSE)
# Performance Category Program:
# 1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
# 2. Find the performance category based on the input score using following criteria:
# a. Above Average: Score greater than 7
# b. Average: Score between 4 and 7(both inclusive)
# c. Below Average: Score lesser than 4
# 3. Output: Print the Performance category
# 4. Additional Step: You can give a prompt of your choice to each category.
# For eg: If score below average “Need to Improve your performance, consistent
# practice will lead to better results”.

# %%
score=int(input("Enter your score: "))
print("-"*80)
if score<=0 or score >10:
    print("Score range should be from 0 to 10 (both inclusive)")
elif score>7:
    print("Above average: keep going and catch the next level")
elif score>=4:
        print("Average: kindly focus on your routs")
else :
    print("Below average:need to improove your performents, consistancy is the key")
